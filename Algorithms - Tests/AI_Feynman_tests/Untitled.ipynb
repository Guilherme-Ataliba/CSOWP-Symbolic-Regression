# %%
# !pip install aifeynman
# Out:
# ...
#   Using cached aifeynman-2.0.7.tar.gz (219 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached sklearn-0.0.post10.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached torch-2.1.0-cp39-cp39-win_amd64.whl (192.2 MB)
# ...
#   Using cached torchvision-0.16.0-cp39-cp39-win_amd64.whl (1.3 MB)
# ...
#   Running setup.py clean for aifeynman
# ...
#   Running setup.py clean for sklearn
# Failed to build aifeynman sklearn
# ...
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [108 lines of output]
# ...

# %%
import aifeynman
import numpy as np
import pandas as pd

X = np.linspace(-10, 10, 1000)
y = X**2 + 3*X - 5

data = pd.DataFrame(np.c_[X], y)
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17284\3506818604.py in <module>
# ----> 1 import aifeynman
#       2 import numpy as np
#       3 import pandas as pd
#       4
#       5 X = np.linspace(-10, 10, 1000)
#
# ModuleNotFoundError: No module named 'aifeynman'

# %%
data.to_csv("data_tests.csv", index=False)

# %%
aifeynman.run_aifeynman("./data_tests.csv/", "example1.txt", 60, "14ops.txt", polyfit_deg=3, NN_epochs=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17284\421724914.py in <module>
# ----> 1 aifeynman.run_aifeynman("./data_tests.csv/", "example1.txt", 60, "14ops.txt", polyfit_deg=3, NN_epochs=500)
#
# NameError: name 'aifeynman' is not defined
