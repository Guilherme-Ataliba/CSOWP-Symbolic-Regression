# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz-10.0.1-win64/bin/'

import sys
sys.path.append('../')

from CSOWP_SR import *
from ExpressionTree import *
from zss import simple_distance, Node

# %%
tree2 = ExpressionTree()
p = tree2.add_root("*")
p1 = tree2.add_left(p, "/")
p2 = tree2.add_left(p1, "square")
tree2.add_left(p2, "0.068")
p3 = tree2.add_right(p1, "tanh")
tree2.add_right(p3, "0.688")
p4 = tree2.add_right(p, "square")
tree2.add_left(p4, "x")

display(tree2.visualize_tree())

# tree_edist = {"nodes": ["*", "/", "square", "0.068", "tanh", "0.688", "square", "x"],
#          "adj": [[1, 6], [2, 4], [3], [], [5], [], [7], []]}
# tree_utils.tree_to_string(tree_edist["nodes"], tree_edist["adj"])

# %%
tree2.parentChildRepr()
# Out:
# {'nodes': ['*', '/', 'square', '0.068', 'tanh', '0.688', 'square', 'x'],
#  'adj': [[1, 6], [2, 4], [3], [], [5], [], [7], []]}

# %%
tree1 = ExpressionTree()
p = tree1.add_root("+")
tree1.add_left(p, "x")
tree1.add_right(p, "2")
tree1.visualize_tree()

# %%
tree2 = ExpressionTree()
p = tree2.add_root("*")
tree2.add_left(p, "2")
tree2.add_right(p, "x")
tree2.visualize_tree()

# %%
A = (
    Node("f")
        .addkid(Node("a")
            .addkid(Node("h"))
            .addkid(Node("c")
                .addkid(Node("l"))))
        .addkid(Node("e"))
    )

[element.label for element in A.iter()]
# Out:
# ['f', 'a', 'e', 'h', 'c', 'l']

# %%
simple_distance(tree1, tree2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 from zss import simple_distance
# ----> 3 simple_distance(tree1, tree2)
#
# File d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\.venv\lib\site-packages\zss\compare.py:162, in simple_distance(A, B, get_children, get_label, label_dist, return_operations)
#     125 def simple_distance(A, B, get_children=Node.get_children,
#     126         get_label=Node.get_label, label_dist=strdist, return_operations=False):
#     127     """Computes the exact tree edit distance between trees A and B.
#     128
#     129     Use this function if both of these things are true:
#    (...)
#     160     :return: An integer distance [0, inf+)
#     161     """
# --> 162     return distance(
#     163         A, B, get_children,
# ...
