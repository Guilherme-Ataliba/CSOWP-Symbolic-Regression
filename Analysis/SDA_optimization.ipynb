# %%
import sys
sys.path.append('../algorithms/')

from CSOWP_SR import *
from ExpressionTree import *
from trainAlgorithm import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Base Test - General Basis Functions

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a),
               "ln": lambda a: np.log(a), "tanh": lambda a: np.tanh(a)}
custom_functions_dict = {"exp-": ["exp(-", ")"]}
weights = {"exp": 4, "exp-": 4, "ln" : 4, "tanh": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/SDA_optimization/base_test_general"
const_range = (-10, 10)
population = 4000
generations = 10
max_expression_size = 5
n_runs = 3
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"
optimization_kind = "dual_annealing"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=True, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights,
                                          optimization_kind=optimization_kind, custom_functions_dict=custom_functions_dict)
# Out:
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_general =-=-=-=-=-=-=-

# %%
with open("Outputs/SDA_optimization/base_test_general/trees/tree-4000-10-2", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Base Test - Specific

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a)}
weights = {"exp": 4, "exp-": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/SDA_optimization/base_test_specific"
const_range = (-10, 10)
population = 4000
generations = 10
max_expression_size = 5
n_runs = 3
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"
optimization_kind = "dual_annealing"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights,
                                          optimization_kind=optimization_kind, custom_functions_dict=custom_functions_dict)
# Out:
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - SDA_optimization/base_test_specific =-=-=-=-=-=-=-

# %%
with open("Outputs/SDA_optimization/base_test_specific/trees/tree-4000-10-0", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()
