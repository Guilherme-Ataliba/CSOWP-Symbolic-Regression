# %%
import sys
sys.path.append('../../algorithms/')
import os
import pickle

from CSOWP_SR import *
from ExpressionTree import *
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz-10.0.1-win64/bin/'

# %%
with open("PSO/F1/trees/tree-4000-5-0", "rb") as file:
    tree = pickle.load(file)

# %%
tree.visualize_tree()

# %%
tree.toSmpExpr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tree.toSmpExpr()
#
# TypeError: ExpressionTree.toSmpExpr() missing 3 required positional arguments: 'operators', 'functions', and 'custom_functions_dict'
