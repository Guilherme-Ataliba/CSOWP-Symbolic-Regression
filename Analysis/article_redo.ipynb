# %%
import sys
sys.path.append('../algorithms/')

from CSOWP_SR import *
from ExpressionTree import *
from trainAlgorithm import *
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def f1(v):
    return 1.57 + 24.3*v

X1 = np.linspace(-2, 2, 1000)
y1 = f1(X1)

def f2(v, y, w):
    return 0.23 + 14.2*(v+y)/(3*w)

v2 = np.linspace(-2, 2, 1000)
y2 = np.linspace(-2, 2, 1000)
w2 = np.linspace(-2, 2, 1000)
y2 = f2(v2, y2, w2)

def f11(x):
    return 6.87 + 11*np.cos(7.23*x**3)

X11 = np.linspace(-2, 2, 1000)
y11 = f11(X11)

def f7(x):
    return 213.809408*(1 - np.exp(-0.547237*x))

X7 = np.linspace(-2, 2, 1000)
y7 = f7(X7)

# %%
n_runs = 3
n_generations = 10
pop_size = 40
random_const_range = (0, 15)

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b),
                "/": lambda a,b: np.divide(a,b), "-": lambda a,b: np.subtract(a,b)}
functions_op = {"sin": lambda a: np.sin(a), "cos": lambda a: np.cos(a),
                "square": lambda a: a**2, "exp-": lambda a: np.exp(-a)}
custom_functions_dict = {"cube": ["(", ")**3"], "square": ["(", ")**2"],
                         "exp-": ["np.exp(-", ")"]}
weigths_op = {"exp-": 4}

# %%
SR = SymbolicRegression(10, functions=functions_op, operators=operators_op, custom_functions_dict=custom_functions_dict)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## F1
# $$1.57 + 24.3*x$$

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
y_scaled = scaler.fit_transform(np.c_[y1])

# %%
x = smp.symbols("x")

# %%
X1.max()
# Out:
# 2.0

# %%
y1_min = f1(0)
y1_max = f1(1)
y1_max
# Out:
# 25.87

# %%
X1 = np.linspace(-1, 1, 1000)
y1 = f1(X1)

# %%
SR.fit(np.c_[X11], y11, feature_names=["x"])

# %%
def func(x):
    return x/(0.456*np.exp(-np.sin(9.312+x)))

# %%
with open("Outputs/article_tests_new/F11/random_LS/trees/tree-2000-8-2", "rb") as file:
    tree = pickle.load(file)
    smp_expr = tree.toSmpExpr(SR._operators, SR._functions, SR.custom_functions_dict)
    
    
display(tree.visualize_tree())
display(tree.toString_smp(SR._operators, SR._functions, SR.custom_functions_dict))
display(smp_expr)
display(SR.fitness_score(tree))

# ======================
smp_func, _ = tree.toFunc(SR._operators, SR._functions, SR.custom_functions_dict)


# smp_expr = smp_expr.subs(x, (x - X1.min())/(X1.max() - X1.min()))
# smp_expr = smp_expr.subs(x, (X1.max() - X1.min())*x + X1.min() )
# smp_expr = (y1.max() - y1.min())*smp_expr + y1.min()
# smp_expr = (y1_max - y1_min)*smp_expr + y1_min
# smp_expr = (smp_expr - y1.min())/(y1.max() - y1.min())
# display(smp_expr)

# smp_func = smp.lambdify(x, smp_expr)

X = np.linspace(-2, 2, 1000)
y = SR.toFunc(tree)(X)
# y = smp_func(X)

plt.plot(X11, y11, label="F1")
plt.plot(X, y, label="Predicted")
# plt.plot(X, smp_func(X))
plt.legend()
plt.show()
# plt.plot(scaler.fit_transform(np.c_[X1]), scaler.fit_transform(np.c_[y1]).reshape(-1), label="F1")
# plt.plot(scaler.fit_transform(np.c_[X1]), scaler.fit_transform(smp_func(scaler.fit_transform(np.c_[X1]))))
# plt.plot(scaler.inverse_transform(np.c_[X]), scaler.inverse_transform(np.c_[y]), label="predicted")
# plt.legend()

# np.mean((y11-SR.toFunc(tree)(X))**2)
# Out:
# '(sin(exp(-(sin(exp(-(sin((((cos((5.237487852960988-exp(-cos(cos(sin(x))))))/1.951647456539537)/0.008013802849953084)/2.506379999107722))*sin(11.854871518903051))))*sin(10.995574205672046))))/sin(6.344859498686108))'
# 16.22452127833339*sin(exp(0.99999999999999665*sin(exp(0.65296989500941938*sin(25.51015279330002*cos(5.237487852960988 - exp(-cos(cos(sin(x))))))))))
# 42.27629414951772

# %% [markdown]
# # F7

# %%
optimization_kind = "LS"
func = f7
x_range = [-1,1]
n_points = 1000
population = 4000
generations = 10
const_range = (0,15)
dir_path = "Outputs/article_tests/F7"

# %%
optimization_opts = ["PSO", "LS", "random_LS", "differential_evolution", "dual_annealing"]
main_path = "Outputs/article_tests/F7/"
paths = [main_path + i for i in optimization_opts]
paths
# Out:
# ['Outputs/article_tests/F7/PSO',
#  'Outputs/article_tests/F7/LS',
#  'Outputs/article_tests/F7/random_LS',
#  'Outputs/article_tests/F7/differential_evolution',
#  'Outputs/article_tests/F7/dual_annealing']

# %%
def create_dirs(path):
    if not os.path.exists(path+"/data"):
        os.makedirs(path+"/data")
    if not os.path.exists(path+"/trees"):
        os.makedirs(path+"/trees")

for path in paths:
    create_dirs(path)

# %%
for optimization_kind in optimization_opts:
    dir_path = main_path + optimization_kind
    X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=True, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op,
                                          optimization_kind=optimization_kind, custom_functions_dict=custom_functions_dict),
# Out:
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F7/dual_annealing =-=-=-=-=-=-=-

# %% [markdown]
# # F1

# %%
optimization_kind = "LS"
func = f1
x_range = [-1,1]
n_points = 1000
population = 4000
generations = 10
const_range = (0,15)
dir_path = "Outputs/article_tests/LS"

# %%
optimization_opts = ["PSO", "LS", "random_LS", "differential_evolution", "dual_annealing"]
main_path = "Outputs/article_tests/"
paths = [main_path + i for i in optimization_opts]
paths
# Out:
# ['Outputs/article_tests/PSO',
#  'Outputs/article_tests/LS',
#  'Outputs/article_tests/random_LS',
#  'Outputs/article_tests/differential_evolution',
#  'Outputs/article_tests/dual_annealing']

# %%
def create_dirs(path):
    if not os.path.exists(path+"/data"):
        os.makedirs(path+"/data")
    if not os.path.exists(path+"/trees"):
        os.makedirs(path+"/trees")

for path in paths:
    create_dirs(path)

# %%
for optimization_kind in optimization_opts:
    dir_path = main_path + optimization_kind
    X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=True, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op,
                                          optimization_kind=optimization_kind, custom_functions_dict=custom_functions_dict)
# Out:
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/PSO =-=-=-=-=-=-=-=-
# iniciou
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16936\1691876664.py in <module>
#       1 for optimization_kind in optimization_opts:
#       2     dir_path = main_path + optimization_kind
# ----> 3     X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
#       4                                           normalize=True, const_range=const_range,
#       5                                           ignore_warning=True, overwrite=True, n_runs=n_runs,
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\trainAlgorithm.py in testAlgorithm(func, x_range, n_points, dir_path, population, generations, max_expression_size, normalize, const_range, normalize_range, ignore_warning, overwrite, n_runs, operators, functions, weights, island_interval, optimization_kind, custom_functions_dict)
#      57
#      58         start_time = time()
# ---> 59         output_AEG = SR.predict()
#      60         end_time = time()
#      61         data = SR.evaluate_tree(output_AEG.sexp)
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\CSOWP_SR.py in predict(self)
#    1189                 out_population = self.insertLambda(out_population, lamb)
#    1190
# -> 1191             champ, islands, in_population = self.populationPruning(in_population, out_population, islands)
#    1192
#    1193         return champ
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\CSOWP_SR.py in populationPruning(self, in_population, out_population, islands)
#    1055                 # print("w.c: ", lamb.c)
#    1056                 # print("w.c.vector: ", lamb.c.vector)
# -> 1057                 out_population = self.insertLambda(out_population, lamb)
#    1058             # print("sai")
#    1059         # Copy and add a few more random individuals
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\CSOWP_SR.py in insertLambda(self, population, lamb)
#     507             w = population[p]
#     508
# --> 509             if (w.aexp == lamb.aexp and len(lamb.pool) >= 1 ): # Checking if abstract trees are equal
#     510                 # print("w")
#     511                 # display(w.aexp.visualize_tree())
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in __eq__(self, other)
#      52
#      53         a = [i.element() for i in self.postorder()]
# ---> 54         b = [i.element() for i in other.postorder()]
#      55
#      56         return a == b
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in <listcomp>(.0)
#      52
#      53         a = [i.element() for i in self.postorder()]
# ---> 54         b = [i.element() for i in other.postorder()]
#      55
#      56         return a == b
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in postorder(self)
#     413     def postorder(self):
#     414         if not self.is_empty():
# --> 415             for p in self._subtree_postorder(self.root()):
#     416                 yield p
#     417
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in _subtree_postorder(self, p)
#     417
#     418     def _subtree_postorder(self, p):
# --> 419         for c in self.children(p):
#     420             for other in self._subtree_postorder(c):
#     421                 yield other
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in children(self, p)
#     103
#     104     def children(self, p):
# --> 105         if self.left(p) is not None:
#     106             yield self.left(p)
#     107         if self.right(p) is not None:
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\ExpressionTree.py in left(self, p)
#      85     def left(self, p):
#      86         node = self._validate(p)
# ---> 87         return self._make_position(node._left)
#      88
#      89     def right(self, p):
#
# KeyboardInterrupt:

# %% [markdown]
# # F11

# %%
optimization_kind = "LS"
func = f11
x_range = [-1,1]
n_points = 1000
population = 4000
generations = 10
const_range = (0,15)
dir_path = "Outputs/article_tests/F11"

# %%
optimization_opts = ["PSO", "LS", "random_LS", "differential_evolution", "dual_annealing"]
main_path = "Outputs/article_tests/F11/"
paths = [main_path + i for i in optimization_opts]
paths
# Out:
# ['Outputs/article_tests/F11/PSO',
#  'Outputs/article_tests/F11/LS',
#  'Outputs/article_tests/F11/random_LS',
#  'Outputs/article_tests/F11/differential_evolution',
#  'Outputs/article_tests/F11/dual_annealing']

# %%
def create_dirs(path):
    if not os.path.exists(path+"/data"):
        os.makedirs(path+"/data")
    if not os.path.exists(path+"/trees"):
        os.makedirs(path+"/trees")

for path in paths:
    create_dirs(path)

# %%
for optimization_kind in optimization_opts:
    dir_path = main_path + optimization_kind
    X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=True, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op,
                                          optimization_kind=optimization_kind, custom_functions_dict=custom_functions_dict)
# Out:
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/random_LS =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/differential_evolution =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/dual_annealing =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 4000 and generation 10 - article_tests/F11/dual_annealing =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 4000 and generation 10 - article_tests/F11/dual_annealing =-=-=-=-=-=-=-=-
# iniciou

# %% [markdown]
# # F2

# %%
n_runs = 3
n_generations = 10
pop_size = 40
random_const_range = (0, 15)

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b),
                "/": lambda a,b: np.divide(a,b), "-": lambda a,b: np.subtract(a,b)}
functions_op = {"sin": lambda a: np.sin(a), "cos": lambda a: np.cos(a),
                "square": lambda a: a**2, "cube": lambda a: a**3}
custom_functions_dict = {"cube": ["(", ")**3"], "square": ["(", ")**2"]}

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
def f2(v, y, w):
    return 0.23 + 14.2*(v+y)/(3*w)

v2 = np.linspace(-2, 2, 1000)
v2 = scaler.fit_transform(np.c_[v2])
y2 = np.linspace(-2, 2, 1000)
y2 = scaler.fit_transform(np.c_[y2])
w2 = np.linspace(-2, 2, 1000)
w2 = scaler.fit_transform(np.c_[w2])
Y2 = f2(v2, y2, w2)
Y2 = scaler.fit_transform(np.c_[Y2]).reshape(-1)
Y2[0] = 0.0

# %%
optimization_kind = "LS"
# func = f11
x_range = [-1,1]
n_points = 1000
population = 40
generations = 10
const_range = (0,15)
n_runs = 3
dir_path = "Outputs/article_tests/F2"

# %%
optimization_opts = ["PSO", "LS", "random_LS", "differential_evolution", "dual_annealing"]
main_path = "Outputs/article_tests/F2/"
paths = [main_path + i for i in optimization_opts]
paths
# Out:
# ['Outputs/article_tests/F2/PSO',
#  'Outputs/article_tests/F2/LS',
#  'Outputs/article_tests/F2/random_LS',
#  'Outputs/article_tests/F2/differential_evolution',
#  'Outputs/article_tests/F2/dual_annealing']

# %%
def create_dirs(path):
    if not os.path.exists(path+"/data"):
        os.makedirs(path+"/data")
    if not os.path.exists(path+"/trees"):
        os.makedirs(path+"/trees")

for path in paths:
    create_dirs(path)

# %%
for optimization_kind in optimization_opts:
    dir_path = main_path + optimization_kind
    for i in range(n_runs):
            print(f"-=-=-=-=-=-=-=-= Training for population {population} and generation {generations} - {dir_path[dir_path.find('/')+1:]} =-=-=-=-=-=-=-=-")
            SR = SymbolicRegression(generations, max_population_size=population,
                                    max_island_count=int(population/10), random_const_range=const_range,
                                    operators=operators_op, functions=functions_op,
                                    optimization_kind=optimization_kind,
                                    custom_functions_dict=custom_functions_dict)
            SR.fit(np.c_[v2, y2, w2], Y2, feature_names=["v", "w", "y"])    
            
            start_time = time()
            output_AEG = SR.predict()
            end_time = time()
            data = SR.evaluate_tree(output_AEG.sexp)
            
            print(f"-=-=-=-=-=-=-= Done training for population {population} and generation {generations} - {dir_path[dir_path.find('/')+1:]} =-=-=-=-=-=-=-")

            # Writing the data =================================

            # In case the output is a constant function
            if data.shape[0] == 1:
                data = np.array([data[0] for i in range(0, 1000)])

            # data = pd.DataFrame(np.c_[X, data], columns=["x", "y"])
            # data.to_csv(dir_path + f"/data/data-{population}.csv", sep=",", index=False)

            # graph = output_AEG.sexp.visualize_tree()
            # graph.render(dir_path + f"/trees/tree-{population}", format="svg")

            with open(dir_path + f"/trees/tree-{population}-{generations}-{i}", "wb") as file:
                pickle.dump(output_AEG.sexp, file)

            with open(dir_path + "/results.csv", "a") as file:
                file.write(f"{SR.fitness_score(output_AEG)},{population},{generations},{end_time - start_time},{i}\n")
# Out:
# -=-=-=-=-=-=-=-= Training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 40 and generation 10 - article_tests/F2/PSO =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 40 and generation 10 - article_tests/F2/LS =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16936\1579309464.py in <module>
#      11
#      12             start_time = time()
# ---> 13             output_AEG = SR.predict()
#      14             end_time = time()
#      15             data = SR.evaluate_tree(output_AEG.sexp)
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\CSOWP_SR.py in predict(self)
#    1156
#    1157
# -> 1158                 lamb, Ic = self.optimizeConstants(in_population[p], g, Ic)
#    1159                 out_population = self.insertLambda(out_population, lamb)
#    1160                 lamb = self.mutateSExp(in_population[p])
#
# d:\Documents\Coding\Repositorios\MyRepositories\Symbolic-Regression\CSOWP_SR\Analysis\../algorithms\CSOWP_SR.py in optimizeConstants(self, me, g, Ic)
#     800
#     801             try:
# --> 802                 params, _ = curve_fit(me.toFunc(self._operators, self._functions, self._feature_names, self.custom_functions_dict),
#     803                                       self._features[self._feature_names[0]], self.y, me.pool[-1].vector)
#     804
#
# d:\Users\lreis\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     832             raise TypeError(f"The number of func parameters={n} must not"
#     833                             f" exceed the number of data points={ydata.size}")
# --> 834         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     835         popt, pcov, infodict, errmsg, ier = res
#     836         ysize = len(infodict['fvec'])
#
# d:\Users\lreis\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     408     if not isinstance(args, tuple):
#     409         args = (args,)
# --> 410     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411     m = shape[0]
#     412
#
# d:\Users\lreis\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# d:\Users\lreis\anaconda3\lib\site-packages\scipy\optimize\_minpack_py.py in func_wrapped(params)
#     483     if transform is None:
#     484         def func_wrapped(params):
# --> 485             return func(xdata, *params) - ydata
#     486     elif transform.ndim == 1:
#     487         def func_wrapped(params):
#
# TypeError: _lambdifygenerated() missing 2 required positional arguments: 'y' and 'c0'

# %%
with open("Outputs/article_tests/F2/PSO/trees/tree-40-10-2", "rb") as file:
    tree = pickle.load(file)
    # print(SR.evaluate_tree(tree))
    # print(SR.y)
tree.visualize_tree()
# Out:
# [       nan 0.002002   0.004004   0.00600601 0.00800801 0.01001001
#  0.01201201 0.01401401 0.01601602 0.01801802 0.02002002 0.02202202
#  0.02402402 0.02602603 0.02802803 0.03003003 0.03203203 0.03403403
#  0.03603604 0.03803804 0.04004004 0.04204204 0.04404404 0.04604605
#  0.04804805 0.05005005 0.05205205 0.05405405 0.05605606 0.05805806
#  0.06006006 0.06206206 0.06406406 0.06606607 0.06806807 0.07007007
#  0.07207207 0.07407407 0.07607608 0.07807808 0.08008008 0.08208208
#  0.08408408 0.08608609 0.08808809 0.09009009 0.09209209 0.09409409
#  0.0960961  0.0980981  0.1001001  0.1021021  0.1041041  0.10610611
#  0.10810811 0.11011011 0.11211211 0.11411411 0.11611612 0.11811812
#  0.12012012 0.12212212 0.12412412 0.12612613 0.12812813 0.13013013
#  0.13213213 0.13413413 0.13613614 0.13813814 0.14014014 0.14214214
#  0.14414414 0.14614615 0.14814815 0.15015015 0.15215215 0.15415415
