# %%
import sys
sys.path.append('../algorithms/')

from CSOWP_SR import *
from ExpressionTree import *
from trainAlgorithm import *
import matplotlib.pyplot as plt

# %% [markdown]
# # Base Test - General Basis Functions

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a),
               "ln": lambda a: np.log(a), "tanh": lambda a: np.tanh(a)}
weights = {"exp": 4, "exp-": 4, "ln" : 4, "tanh": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_general"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 1
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_general =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_general =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_general/trees/tree-5000-5-0", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Base Test - Specific

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a)}
weights = {"exp": 4, "exp-": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_specific"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 1
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_specific/trees/tree-5000-5-0", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X = np.linspace(-5, 15, 1000)
y = func(X)

scaler.fit_transform(np.c_[y])

def unorm_func(X, y):
    # x_norm = (X - X.min())/(X.max() - X.min())
    x_norm = (X.max() - X.min())*X + X.min()
    return (y.max() - y.min())*(np.exp(-x_norm * np.exp(-5.293 * x_norm))) + y.min()
    # return (np.exp(-x_norm * np.exp(-5.293 * x_norm)) - y.min())/(y.max() - y.min())

# %%
import pandas as pd
data = pd.read_csv("Outputs/base_test_specific/data/data-5000.csv", sep=",")

# %%
X = np.linspace(-5, 15, 1000)
y = func(X)

plt.plot(scaler.fit_transform(np.c_[X]), scaler.fit_transform(np.c_[y]))
# plt.plot(X, unorm_func(X, y))
# plt.plot(X, scaler.inverse_transform(np.c_[data.y]))
plt.plot(data.x, data.y)
plt.show()

# %% [markdown]
# # Islands Tests

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a),
               "ln": lambda a: np.log(a), "tanh": lambda a: np.tanh(a)}
weights = {"exp": 4, "exp-": 4, "ln" : 4, "tanh": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_10"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 1
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_10 =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_10 =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_11/trees/tree-5000-5-0", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Islands Tests (1,1)

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a),
               "ln": lambda a: np.log(a), "tanh": lambda a: np.tanh(a)}
weights = {"exp": 4, "exp-": 4, "ln" : 4, "tanh": 4}
island_interval = (1,1)

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_11"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 1
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights,
                                          island_interval=island_interval)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_11 =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_11 =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_11/trees/tree-5000-5-0", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Base Test - Specific

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a)}
weights = {"exp": 4, "exp-": 4}

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_specific"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 3
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_specific/trees/tree-5000-5-1", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Base Test - Specific (2,1)

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a)}
weights = {"exp": 4, "exp-": 4}
island_interval = (2,1)

# %%
def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(0, 20, 1000)
y = func(X)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_specific_01"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 3
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
                                          max_expression_size, normalize=True, const_range=const_range,
                                          ignore_warning=True, overwrite=False, n_runs=n_runs, 
                                          functions=functions_op, operators = operators_op, weights = weights,
                                          island_interval=island_interval)
# Out:
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-
# -=-=-=-=-=-=-=-= Training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-=-
# iniciou
# iniciou
# iniciou
# iniciou
# iniciou
# -=-=-=-=-=-=-= Done training for population 5000 and generation 5 - base_test_specific_01 =-=-=-=-=-=-=-

# %%
with open("Outputs/base_test_specific_01/trees/tree-5000-5-1", "rb") as file:
    tree = pickle.load(file)
tree.visualize_tree()

# %% [markdown]
# # Standardized - Specific

# %%
operators_op = {"+": lambda a,b: np.add(a,b), "*": lambda a,b: np.multiply(a,b)}
functions_op = {"exp-": lambda a: np.exp(-a), "exp": lambda a: np.exp(a)}
weights_op = {"exp": 4, "exp-": 4}

# %%
from sklearn.preprocessing import StandardScaler

def func(x):
    a=10
    b=-0.5
    c=-0.5
    d=2
    return a*np.exp(b*np.exp(c*x + d))

X = np.linspace(-5, 15, 1000)
y = func(X)

sscaler = StandardScaler()
X_scaled = sscaler.fit_transform(np.c_[X])
y_scaled = sscaler.fit_transform(np.c_[y]).reshape(-1)

x_range = [-5, 15]
n_points = 1000
dir_path = "Outputs/base_test_standardized"
const_range = (-10, 10)
population = 5000
generations = 5
max_expression_size = 5
n_runs = 3
real_func_string = r"10e^{-0.5e^{-0.5x+2}}"

# X, y, operators, functions = testAlgorithm(func, x_range, n_points, dir_path, population, generations,
#                                           max_expression_size, normalize=True, const_range=const_range,
#                                           ignore_warning=True, overwrite=False, n_runs=n_runs, 
#                                           functions=functions_op, operators = operators_op, weights = weights,
#                                           island_interval=island_interval)

# %%
# Training the model =============StandardScaler=======
for i in range(n_runs):
    print(f"-=-=-=-=-=-=-=-= Training for population {population} and generation {generations} - {dir_path[dir_path.find('/')+1:]} =-=-=-=-=-=-=-=-")
    SR = SymbolicRegression(generations, max_expression_size, max_population_size=population,
                            max_island_count=int(population/10), random_const_range=const_range,
                            operators=operators_op, functions=functions_op, weights=weights_op)
    SR.fit(X, y, feature_names=["x"])

    start_time = time()
    output_AEG = SR.predict()
    end_time = time()
    data = SR.evaluate_tree(output_AEG.sexp)

    print(f"-=-=-=-=-=-=-= Done training for population {population} and generation {generations} - {dir_path[dir_path.find('/')+1:]} =-=-=-=-=-=-=-")

    # Writing the data =================================

    # In case the output is a constant function
    # if data.shape[0] == 1:
    #     data = np.array([data[0] for i in range(0, 1000)])

    # data = pd.DataFrame(np.c_[X, data], columns=["x", "y"])
    # data.to_csv(dir_path + f"/data/data-{population}.csv", sep=",", index=False)

    # graph = output_AEG.sexp.visualize_tree()
    # graph.render(dir_path + f"/trees/tree-{population}", format="svg")

    with open(dir_path + f"/trees/tree-{population}-{generations}-{i}", "wb") as file:
        pickle.dump(output_AEG.sexp, file)

    with open(dir_path + "/results.csv", "a") as file:
        file.write(f"{SR.fitness_score(output_AEG)},{population},{generations},{end_time - start_time},{i}\n")
